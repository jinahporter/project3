# %% [markdown]
# # Classification model - Saving Pickle File

# %%
import os
import re
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load the data

# %%
data = pd.read_csv('ppp data.csv')
print(f"Shape of the data is: {data.shape}")
data.head()
# Out:
# Shape of the data is: (417253, 10)
#   LoanAmount        City State    Zip  NAICSCode  \
# 0     133500    Pasadena    TX  77502   111110.0
# 1     125300     Houston    TX  77041   111110.0
# 2     124938       PLANO    TX  75024   111110.0
# 3     118922  Sugar Land    TX  77478   111110.0
# 4     109952     Houston    TX  77007   111110.0
#
#                       BusinessType DateApproved  \
# 0         Subchapter S Corporation    4/29/2020
# 1                      Corporation    4/29/2020
# 2                      Corporation    4/14/2020
# 3  Limited  Liability Company(LLC)    4/27/2020
# 4                      Corporation    4/28/2020
#
#                               Lender     CD  LoanRange
# 0  Capital One, National Association  TX-29          6
# 1                      Comerica Bank  TX-07          6
# 2             Veritex Community Bank  TX-03          5
# 3                    Allegiance Bank  TX-22          5
# 4                    Allegiance Bank  TX-18          5

# %% [markdown]
# ### Check how many `null/Nan` values are in each column

# %%
data.isnull().sum()
# Out:
# LoanAmount         0
# City              14
# State              0
# Zip                0
# NAICSCode       9162
# BusinessType     258
# DateApproved       0
# Lender             0
# CD                18
# LoanRange          0
# dtype: int64

# %% [markdown]
# ### View the possible labels for the columns that have some null values

# %%
# # we are intentionally narrowing the scope of the loan data details for those with strong completion entries, minimal nulls
# contains_null = ['Zip', 'BusinessType', 'DateApproved', 'Lender','CD', 'LoanRange']

# for col in contains_null:
#     print(f"List of unique labels for {col}:::{set(data[col])}")

# %% [markdown]
# ### Clean up null values
#
# For the sake of simplicity, I'm going to make a few assumptions:
#
# - `Dependents`: Assumption that there are no dependents (0: 345 | 1: 102 | 2: 101 | 3+: 51)
# - `Self_Employed`: Assumption that the applicant is not self-employed (No: 500 | Yes: 82)
# - `Credit_History`: Assumption that the person has a credit history (True: 475 | False: 89)
# - `Married`: If nothing specified, applicant is not married
# - `Gender`: Assuming the gender is Male for the missing values (Male: 489 | Female: 112)

# %%
# data['Dependents'] = data['Dependents'].fillna('0')
# data['Self_Employed'] = data['Self_Employed'].fillna('No')
# data['Credit_History'] = data['Credit_History'].fillna(1)
# data['Married'] = data['Married'].fillna('No')
# data['Gender'] = data['Gender'].fillna('Male')

# %%
# investigate rows with null values
data[data.isnull().any(axis=1)]
# Out:
#                 LoanAmount         City State    Zip  NAICSCode  \
# 2863                 37053       WALLIS    TX  77485   111998.0
# 5759                 21396  FLORESVILLE    TX  78114   112990.0
# 16293                15102    ROSENBERG    TX  77471   236115.0
# 28793                45001       DALLAS    TX  75228   238160.0
# 30297               136475    KENNEDALE    TX  76060   238210.0
# ...                    ...          ...   ...    ...        ...
# 416999  e $150,000-350,000     Berkeley    TX  75081        NaN
# 417101  e $150,000-350,000    RIVERSIDE    TX  75247        NaN
# 417135  e $150,000-350,000      REEDLEY    TX  78753        NaN
# 417154  e $150,000-350,000      Yucaipa    TX  77598        NaN
# 417195  e $150,000-350,000  PASO ROBLES    TX  75074        NaN
#
#                            BusinessType DateApproved  \
# 2863                                NaN     5/3/2020
# 5759                                NaN     5/3/2020
# 16293                               NaN     5/3/2020
# 28793                               NaN     5/1/2020
# 30297                               NaN     5/1/2020
# ...                                 ...          ...
# 416999  Limited  Liability Company(LLC)     5/1/2020
# 417101                      Corporation     5/1/2020
# 417135                      Corporation     5/1/2020
# 417154                      Corporation     5/1/2020
# 417195                      Corporation     5/3/2020
#
#                                            Lender     CD  LoanRange
# 2863       Wells Fargo Bank, National Association  TX-10          2
# 5759       Wells Fargo Bank, National Association  TX-28          1
# 16293      Wells Fargo Bank, National Association  TX-22          1
# 28793   JPMorgan Chase Bank, National Association  TX-05          2
# 30297   JPMorgan Chase Bank, National Association  TX-06          6
# ...                                           ...    ...        ...
# 416999  JPMorgan Chase Bank, National Association  TX-32          7
# 417101  JPMorgan Chase Bank, National Association  TX-30          7
# 417135  JPMorgan Chase Bank, National Association  TX-10          7
# 417154  JPMorgan Chase Bank, National Association  TX-22          7
# 417195     Wells Fargo Bank, National Association  TX-03          7
#
# [9424 rows x 10 columns]

# %%
# only take rows of businesses that CD is not null

data = data[data['CD'].notna()]
data.head()

#drop rows with NA cities
data = data[data['City'].notna()]

# drop rows with NA NAICS code
data = data[data['NAICSCode'].notna()]

#drop rows with NA business type
data = data[data['BusinessType'].notna()]

data.isnull().sum()

data.shape

data.head()

data['NAICSCode'] = data['NAICSCode'].astype(int)

data
# Out:
#                 LoanAmount            City State    Zip  NAICSCode  \
# 0                   133500        Pasadena    TX  77502     111110
# 1                   125300         Houston    TX  77041     111110
# 2                   124938           PLANO    TX  75024     111110
# 3                   118922      Sugar Land    TX  77478     111110
# 4                   109952         Houston    TX  77007     111110
# ...                    ...             ...   ...    ...        ...
# 417248  e $150,000-350,000       Lafayette    TX  77064     541611
# 417249  e $150,000-350,000      SANTA ROSA    TX  78205     531312
# 417250  e $150,000-350,000  RANCHO CORDOVA    TX  77803     442210
# 417251  e $150,000-350,000       LOS ALTOS    TX  78230     492210
# 417252  e $150,000-350,000     Bakersfield    TX  75201     517919
#
#                            BusinessType DateApproved  \
# 0              Subchapter S Corporation    4/29/2020
# 1                           Corporation    4/29/2020
# 2                           Corporation    4/14/2020
# 3       Limited  Liability Company(LLC)    4/27/2020
# 4                           Corporation    4/28/2020
# ...                                 ...          ...
# 417248  Limited  Liability Company(LLC)     5/1/2020
# 417249                      Corporation    4/14/2020
# 417250  Limited  Liability Company(LLC)    4/27/2020
# 417251                      Corporation    4/30/2020
# 417252  Limited  Liability Company(LLC)    7/13/2020
#
#                                            Lender     CD  LoanRange
# 0               Capital One, National Association  TX-29          6
# 1                                   Comerica Bank  TX-07          6
# 2                          Veritex Community Bank  TX-03          5
# 3                                 Allegiance Bank  TX-22          5
# 4                                 Allegiance Bank  TX-18          5
# ...                                           ...    ...        ...
# 417248  JPMorgan Chase Bank, National Association  TX-07          7
# 417249                         Vantage Bank Texas  TX-35          7
# 417250                  Spirit of Texas Bank, SSB  TX-17          7
# 417251                        Randolph-Brooks FCU  TX-21          7
# 417252                        Texas Security Bank  TX-30          7
#
# [407829 rows x 10 columns]

# %% [markdown]
# ### View cleaned up values

# %%
# label_cols = ['LoanAmount', 'City', 'State', 'Zip', 'NAICSCode', 'BusinessType', 'DateApproved', 'Lender', 'CD', 'LoanRange']

# for col in label_cols:
#     print(f"List of unique labels for {col} ::: {set(data[col])}")

# %%
## read in data for NAICS code

naics = pd.read_csv('US-Business-Profiles-By-Sales-and-Employees (1).csv')

naics.head()
# Out:
#   NAICS 1 Code               NAICS 1 Description
# 0       111110                   Soybean Farming
# 1       111120  Oilseed (except Soybean) Farming
# 2       111130          Dry Pea and Bean Farming
# 3       111140                     Wheat Farming
# 4       111150                      Corn Farming

# %%
naics.dtypes
naics[naics.isnull().any(axis=1)]

data2 = naics.drop([1045])
data2['NAICS 1 Code'] = data2['NAICS 1 Code'].astype(int)

data2
# Out:
#       NAICS 1 Code                                NAICS 1 Description
# 0           111110                                    Soybean Farming
# 1           111120                   Oilseed (except Soybean) Farming
# 2           111130                           Dry Pea and Bean Farming
# 3           111140                                      Wheat Farming
# 4           111150                                       Corn Farming
# ...            ...                                                ...
# 1040        926140  Regulation of Agricultural Marketing and Commo...
# 1041        926150  Regulation, Licensing, and Inspection of Misce...
# 1042        927110                      Space Research and Technology
# 1043        928110                                  National Security
# 1044        928120                              International Affairs
#
# [1045 rows x 2 columns]

# %%
## merge tables 

data3 = pd.merge(data, data2, left_on='NAICSCode', right_on='NAICS 1 Code') 

data3
# Out:
#                   LoanAmount        City State    Zip  NAICSCode  \
# 0                     133500    Pasadena    TX  77502     111110
# 1                     125300     Houston    TX  77041     111110
# 2                     124938       PLANO    TX  75024     111110
# 3                     118922  Sugar Land    TX  77478     111110
# 4                     109952     Houston    TX  77007     111110
# ...                      ...         ...   ...    ...        ...
# 397943  d $350,000-1 million     PHOENIX    TX  79072     325193
# 397944  d $350,000-1 million      TUCSON    TX  79045     325193
# 397945  d $350,000-1 million  Scottsdale    TX  75034     325193
# 397946  d $350,000-1 million        YUMA    TX  77002     212113
# 397947  d $350,000-1 million     PHOENIX    TX  78257     336419
#
#                            BusinessType DateApproved  \
# 0              Subchapter S Corporation    4/29/2020
# 1                           Corporation    4/29/2020
# 2                           Corporation    4/14/2020
# 3       Limited  Liability Company(LLC)    4/27/2020
# 4                           Corporation    4/28/2020
# ...                                 ...          ...
# 397943  Limited  Liability Company(LLC)    4/15/2020
# 397944  Limited  Liability Company(LLC)    4/15/2020
# 397945  Limited  Liability Company(LLC)    4/10/2020
# 397946  Limited  Liability Company(LLC)     4/9/2020
# 397947                      Corporation    4/14/2020
#
#                                               Lender     CD  LoanRange  \
# 0                  Capital One, National Association  TX-29          6
# 1                                      Comerica Bank  TX-07          6
# 2                             Veritex Community Bank  TX-03          5
# 3                                    Allegiance Bank  TX-22          5
# 4                                    Allegiance Bank  TX-18          5
# ...                                              ...    ...        ...
# 397943     JPMorgan Chase Bank, National Association  TX-19          8
# 397944     JPMorgan Chase Bank, National Association  TX-19          8
# 397945     JPMorgan Chase Bank, National Association  TX-26          8
# 397946                             Gulf Capital Bank  TX-18          8
# 397947  Business Bank of Texas, National Association  TX-23          8
#
#         NAICS 1 Code                                NAICS 1 Description
# 0             111110                                    Soybean Farming
# 1             111110                                    Soybean Farming
# 2             111110                                    Soybean Farming
# 3             111110                                    Soybean Farming
# 4             111110                                    Soybean Farming
# ...              ...                                                ...
# 397943        325193                        Ethyl Alcohol Manufacturing
# 397944        325193                        Ethyl Alcohol Manufacturing
# 397945        325193                        Ethyl Alcohol Manufacturing
# 397946        212113                                  Anthracite Mining
# 397947        336419  Other Guided Missile and Space Vehicle Parts a...
#
# [397948 rows x 12 columns]

# %% [markdown]
# ### Encode categorical fields
# We have a lot of `string` labels that we encounter in `Gender`, `Married`, `Education`, `Self_Employed` & `Property_Area` columns.

# %%
# create dictionaries to map fields to numeric values
# business_type = {'Limited  Liability Company(LLC)': 0, 'Limited Liability Partnership' : 1, 'Corporation' : 2, 
#                  'Subchapter S Corporation': 3, 'Cooperative': 4, 'Employee Stock Ownership Plan(ESOP)': 5, 
#                  'Independent Contractors': 6, 'Joint Venture': 7, 'Non-Profit Childcare Center': 8, 
#                  'Non-Profit Organization': 9, 'Partnership': 10, 'Professional Association': 11, 
#                  'Rollover as Business Space Start-Ups (ROB': 12, 'Self-Employed Individuals': 13, 
#                  'Sole Proprietorship': 14, 'Tenant in Common': 15, 'Trust': 16 } 


# replace values in each column according to the dictionaries above
# data2.replace({'BusinessType': business_type}).astype(int)
# # Get dummy variables for nominal property column
clean_data = pd.get_dummies(data3, columns=["BusinessType"])

clean_data.head()
clean_data.keys()
# Out:
# Index(['LoanAmount', 'City', 'State', 'Zip', 'NAICSCode', 'DateApproved',
#        'Lender', 'CD', 'LoanRange', 'NAICS 1 Code', 'NAICS 1 Description',
#        'BusinessType_Cooperative', 'BusinessType_Corporation',
#        'BusinessType_Employee Stock Ownership Plan(ESOP)',
#        'BusinessType_Independent Contractors', 'BusinessType_Joint Venture',
#        'BusinessType_Limited  Liability Company(LLC)',
#        'BusinessType_Limited Liability Partnership',
#        'BusinessType_Non-Profit Childcare Center',
#        'BusinessType_Non-Profit Organization', 'BusinessType_Partnership',
#        'BusinessType_Professional Association',
#        'BusinessType_Rollover as Business Start-Ups (ROB',
#        'BusinessType_Self-Employed Individuals',
#        'BusinessType_Sole Proprietorship',
#        'BusinessType_Subchapter S Corporation',
#        'BusinessType_Tenant in Common', 'BusinessType_Trust'],
#       dtype='object')

# %% [markdown]
# ### Train/Test Split

# %%
# store the target variable in y and everything else goes in X
y = clean_data['Lender']

# we're also dropping Load_ID because it adds no value to the prediction
X = clean_data.drop(['LoanAmount', 'City', 'DateApproved', 'CD', 'State', 'Lender', 'NAICS 1 Description'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=3)

X_train.shape
# Out:
# (298461, 21)

# %% [markdown]
# ### Fill the nulls for the continuous variables with the mean values of that column

# %%
# X_train['Loan_Amount_Term'] = X_train['Loan_Amount_Term'].fillna(X_train['Loan_Amount_Term'].mean())
# X_train['LoanAmount'] = X_train['LoanAmount'].fillna(X_train['LoanAmount'].mean())
# X_test['Loan_Amount_Term'] = X_test['Loan_Amount_Term'].fillna(X_test['Loan_Amount_Term'].mean())
# X_test['LoanAmount'] = X_test['LoanAmount'].fillna(X_test['LoanAmount'].mean())


# # View the datatypes of all columns
# X_train.dtypes

# %% [markdown]
# ### Confirm that we no longer have any nulls

# %%
X_train.isnull().sum()
# Out:
# Zip                                                 0
# NAICSCode                                           0
# LoanRange                                           0
# NAICS 1 Code                                        0
# BusinessType_Cooperative                            0
# BusinessType_Corporation                            0
# BusinessType_Employee Stock Ownership Plan(ESOP)    0
# BusinessType_Independent Contractors                0
# BusinessType_Joint Venture                          0
# BusinessType_Limited  Liability Company(LLC)        0
# BusinessType_Limited Liability Partnership          0
# BusinessType_Non-Profit Childcare Center            0
# BusinessType_Non-Profit Organization                0
# BusinessType_Partnership                            0
# BusinessType_Professional Association               0
# BusinessType_Rollover as Business Start-Ups (ROB    0
# BusinessType_Self-Employed Individuals              0
# BusinessType_Sole Proprietorship                    0
# BusinessType_Subchapter S Corporation               0
# BusinessType_Tenant in Common                       0
# BusinessType_Trust                                  0
# dtype: int64

# %% [markdown]
# ### Create the classifier model and the parameter grid for GridSearch

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

param_grid = {"n_estimators" : [10, 20, 50, 100],
             "max_depth" : [None, 6, 8, 10],
             "max_leaf_nodes": [None, 5, 10, 20], 
             "min_impurity_split": [0.1, 0.2, 0.3, 0.4]}

# %% [markdown]
# ### Initialize the GridSearch to tune my hyperparameters

# %%
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(model, param_grid=param_grid, cv=3, verbose=2)

# %% [markdown]
# ### Execute the tuning

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 256 candidates, totalling 768 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=  45.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   45.4s remaining:    0.0s
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=  45.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=  46.6s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total= 4.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total= 4.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total= 4.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total= 9.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total= 9.4min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total= 9.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=  44.1s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=  45.7s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=  45.9s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total= 4.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total= 4.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total= 4.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total= 9.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total= 9.4min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total= 9.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=  43.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=  44.8s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=  46.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total= 4.4min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total= 4.4min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total= 4.4min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total= 9.2min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total= 9.2min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total= 9.3min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=  42.9s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=  43.3s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=  43.1s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total= 4.3min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total= 4.3min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total= 4.3min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total= 9.1min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total= 8.9min
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total= 9.1min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=   9.9s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=   9.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=   9.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=  17.9s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=  17.9s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=  17.9s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=  42.8s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=  43.1s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=  43.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=   9.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=   9.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=   9.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=  17.9s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=  18.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=  18.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=  43.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=  43.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=  43.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   9.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   9.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   9.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=  17.9s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=  18.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=  18.1s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50, total=  43.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50, total=  43.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50, total=  43.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10, total=   9.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10, total=   9.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10, total=   9.4s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20, total=  17.8s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20, total=  17.8s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20, total=  17.8s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50, total=  42.8s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50, total=  42.4s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50, total=  43.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100, total= 1.4min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10, total=   9.8s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10, total=   9.7s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10, total=  10.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20, total=  19.0s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20, total=  18.9s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20, total=  19.0s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50, total=  45.9s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50, total=  45.6s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50, total=  45.7s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=   9.9s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=  10.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=  10.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=  19.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=  19.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=  19.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=  46.0s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=  46.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=  46.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=  10.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=  10.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=  10.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=  19.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=  19.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=  19.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=  46.8s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=  46.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=  46.7s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=  10.0s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=  10.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=  10.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=  19.0s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=  19.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=  19.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=  45.8s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=  45.8s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=  45.8s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=  10.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=  10.5s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=  10.6s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=  19.7s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=  19.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=  20.1s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=  45.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=  47.6s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=  48.0s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=  10.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=  10.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=  10.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=  19.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=  19.6s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=  19.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=  47.3s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=  47.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=  44.5s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total= 1.5min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   9.5s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   9.6s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   9.7s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=  18.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=  18.1s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=  18.1s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=  44.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=  47.6s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=  47.9s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=  10.6s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=  10.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=  10.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=  19.6s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=  19.7s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=  19.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=  49.3s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=  48.5s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=  47.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total= 1.6min
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total= 1.5min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=  10.1s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=   9.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=   9.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total=  18.9s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total=  19.1s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total=  19.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total=  47.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total=  48.3s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total=  48.8s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=  10.6s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=  10.6s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=  10.5s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total=  20.0s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total=  20.0s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total=  20.1s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total=  48.1s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total=  46.8s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total=  44.5s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=  10.6s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=  10.6s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=  10.6s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total=  19.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total=  19.9s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total=  20.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total=  46.8s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total=  48.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total=  48.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total= 1.5min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=  10.6s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=  10.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=  10.0s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total=  20.5s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total=  20.1s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total=  19.9s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total=  47.5s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total=  47.3s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total=  47.6s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total= 1.6min
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=  10.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=  10.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=  10.1s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=  18.9s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=  19.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=  18.9s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=  45.5s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=  45.6s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=  46.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=  10.1s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=  10.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=  10.1s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=  19.1s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=  19.1s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=  19.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=  45.8s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=  46.1s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=  46.3s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total= 1.5min
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total= 1.5min
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total= 1.5min
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   9.9s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   9.8s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   9.9s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=  18.8s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=  18.8s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=  19.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50
# ...
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=   9.5s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=   9.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=  17.6s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=  17.8s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=  17.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=  42.6s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=  42.6s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=  43.4s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=   9.5s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=   9.3s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=   9.3s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=  17.8s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=  17.6s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=  17.5s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=  42.8s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=  42.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=  42.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=   9.5s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=   9.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=   9.6s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=  17.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=  17.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=  17.5s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=  42.4s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=  42.3s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=  43.0s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=   9.8s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=   9.6s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=   9.8s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=  18.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=  18.5s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=  18.5s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=  44.1s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=  44.5s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=  44.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total= 1.5min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=   9.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=   9.8s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=   9.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=  18.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=  18.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=  18.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=  43.8s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=  44.8s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=  43.9s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total= 1.5min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   9.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   9.6s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   9.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=  18.1s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=  18.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=  18.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=  43.8s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=  44.0s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=  44.0s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total= 1.4min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total= 1.5min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=   9.6s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=   9.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=   9.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=  18.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=  18.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=  18.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=  44.1s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=  44.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=  44.1s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total= 1.5min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total= 1.5min
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total= 1.5min
# [Parallel(n_jobs=1)]: Done 768 out of 768 | elapsed: 683.0min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [None, 6, 8, 10],
#                          'max_leaf_nodes': [None, 5, 10, 20],
#                          'min_impurity_split': [0.1, 0.2, 0.3, 0.4],
#                          'n_estimators': [10, 20, 50, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %% [markdown]
# ### View the results

# %%
print(f"Best parameters: {grid.best_params_}")
print(f"Test set score: {grid.score(X_test, y_test)}")
# Out:
# Best parameters: {'max_depth': 10, 'max_leaf_nodes': None, 'min_impurity_split': 0.4, 'n_estimators': 100}
# Test set score: 0.1632776141606441

# %% [markdown]
# # Saving the model

# %%
import pickle

with open('RF_model.pkl','wb') as f:
    pickle.dump(grid, f)

# %% [markdown]
# ### Loading the saved model

# %%
with open('RF_model.pkl', 'rb') as f:
    model = pickle.load(f)

# %% [markdown]
# ### Test the saved model

# %%
print(f"Test set score: {model.score(X_test, y_test)}")
# Out:
# Test set score: 0.1632776141606441

# %%
model
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [None, 6, 8, 10],
#                          'max_leaf_nodes': [None, 5, 10, 20],
#                          'min_impurity_split': [0.1, 0.2, 0.3, 0.4],
#                          'n_estimators': [10, 20, 50, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)
