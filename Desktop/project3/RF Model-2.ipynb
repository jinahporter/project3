# %% [markdown]
# ## Classification Model

# %%
#import things
import os
import re
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
## load data

data = pd.read_csv("application_record-Copy1.csv")
data.shape
data.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0             NaN
# 1           1                1           0           0             NaN
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS
# 0              2.0
# 1              2.0
# 2              2.0
# 3              1.0
# 4              1.0

# %%
## check null values 

data.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
data[data.isnull().any(axis=1)]
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 7       5008812           F            N               Y             0
# 8       5008813           F            N               Y             0
# 9       5008814           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438549  6840098           F            N               Y             0
# 438550  6840100           F            N               Y             0
# 438551  6840102           F            N               Y             0
# 438552  6840104           M            N               Y             0
# 438555  6842765           F            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 7               283500.0        Pensioner               Higher education
# 8               283500.0        Pensioner               Higher education
# 9               283500.0        Pensioner               Higher education
# ...                  ...              ...                            ...
# 438549          135000.0        Pensioner  Secondary / secondary special
# 438550          135000.0        Pensioner  Secondary / secondary special
# 438551          135000.0        Pensioner  Secondary / secondary special
# 438552          135000.0        Pensioner  Secondary / secondary special
# 438555           72000.0        Pensioner  Secondary / secondary special
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0          Civil marriage   Rented apartment      -12005          -4542
# 1          Civil marriage   Rented apartment      -12005          -4542
# 7               Separated  House / apartment      -22464         365243
# 8               Separated  House / apartment      -22464         365243
# 9               Separated  House / apartment      -22464         365243
# ...                   ...                ...         ...            ...
# 438549          Separated  House / apartment      -22717         365243
# 438550          Separated  House / apartment      -22717         365243
# 438551          Separated  House / apartment      -22717         365243
# 438552          Separated  House / apartment      -22717         365243
# 438555            Married  House / apartment      -21673         365243
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 7                1                0           0           0             NaN
# 8                1                0           0           0             NaN
# 9                1                0           0           0             NaN
# ...            ...              ...         ...         ...             ...
# 438549           1                0           0           0             NaN
# 438550           1                0           0           0             NaN
# 438551           1                0           0           0             NaN
# 438552           1                0           0           0             NaN
# 438555           1                0           0           0             NaN
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 7                   1.0
# 8                   1.0
# 9                   1.0
# ...                 ...
# 438549              1.0
# 438550              1.0
# 438551              1.0
# 438552              1.0
# 438555              2.0
#
# [134203 rows x 18 columns]

# %%
data = data.drop(['OCCUPATION_TYPE'], axis = 1)

# %%
data.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_BIRTH               int64
# DAYS_EMPLOYED            int64
# FLAG_MOBIL               int64
# FLAG_WORK_PHONE          int64
# FLAG_PHONE               int64
# FLAG_EMAIL               int64
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
# create dictionaries to map fields to numeric values
gender_values = {'F' : 0, 'M' : 1} 
own_car = {'N' : 0, 'Y' : 1}
own_realty = {'N' : 0, 'Y' : 1}
education_values = {'Lower secondary' : 0, 'Secondary / secondary special' : 1, 'Incomplete higher': 2, 'Higher education': 3, 'Academic degree': 4}
fam_stat = {'Single / not married': 0, 'Separated': 1, 'Widow':2, "Civil marriage": 3, 'Married': 4 }
work = {'Student': 0, 'Pensioner': 1, 'State servant': 2, 'Commercial associate': 3, 'State servant': 4, 'Working': 5}
house = {'With parents': 0, 'Municipal apartment': 1, 'Co-op apartment': 2, 'Office apartment': 3, 'Rented apartment': 4, 'House / apartment': 5}

# %%
data.replace({'CODE_GENDER': gender_values, 'FLAG_OWN_CAR': own_car, 'FLAG_OWN_REALTY': own_realty, 'NAME_EDUCATION_TYPE': education_values, 'NAME_FAMILY_STATUS': fam_stat, 'NAME_INCOME_TYPE': work, 'NAME_HOUSING_TYPE': house}, inplace=True)

# %%
data.head()
# Out:
#         ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804            1             1                1             0
# 1  5008805            1             1                1             0
# 2  5008806            1             1                1             0
# 3  5008808            0             0                1             0
# 4  5008809            0             0                1             0
#
#    AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0          427500.0                 5                    3
# 1          427500.0                 5                    3
# 2          112500.0                 5                    1
# 3          270000.0                 3                    1
# 4          270000.0                 3                    1
#
#    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0                   3                  4      -12005          -4542
# 1                   3                  4      -12005          -4542
# 2                   4                  5      -21474          -1134
# 3                   0                  5      -19110          -3051
# 4                   0                  5      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS
# 0           1                1           0           0              2.0
# 1           1                1           0           0              2.0
# 2           1                0           0           0              2.0
# 3           1                0           1           1              1.0
# 4           1                0           1           1              1.0

# %%
#find unique values and categorize them 
data['NAME_INCOME_TYPE'].unique()
# data['NAME_EDUCATION_TYPE'].unique()
# data['NAME_FAMILY_STATUS'].unique()
data['NAME_HOUSING_TYPE'].unique()
# Out:
# array([4, 5, 1, 0, 2, 3], dtype=int64)

# %%
# change string values to categorical data
data['NAME_INCOME_TYPE'] = data['NAME_INCOME_TYPE'].astype('category')
data['NAME_EDUCATION_TYPE'] = data['NAME_EDUCATION_TYPE'].astype('category')
data['NAME_FAMILY_STATUS'] = data['NAME_FAMILY_STATUS'].astype('category')
data['NAME_HOUSING_TYPE'] = data['NAME_HOUSING_TYPE'].astype('category')

# change income total and count of family members to integers
data['CNT_CHILDREN'] = data['CNT_CHILDREN'].astype('int')
data['AMT_INCOME_TOTAL'] = data['AMT_INCOME_TOTAL'].astype('int')
data['CNT_FAM_MEMBERS'] = data['CNT_FAM_MEMBERS'].astype('int')

# %%
data.dtypes
# Out:
# ID                        int64
# CODE_GENDER               int64
# FLAG_OWN_CAR              int64
# FLAG_OWN_REALTY           int64
# CNT_CHILDREN              int32
# AMT_INCOME_TOTAL          int32
# NAME_INCOME_TYPE       category
# NAME_EDUCATION_TYPE    category
# NAME_FAMILY_STATUS     category
# NAME_HOUSING_TYPE      category
# DAYS_BIRTH                int64
# DAYS_EMPLOYED             int64
# FLAG_MOBIL                int64
# FLAG_WORK_PHONE           int64
# FLAG_PHONE                int64
# FLAG_EMAIL                int64
# CNT_FAM_MEMBERS           int32
# dtype: object

# %%
data.isnull().sum()
# Out:
# ID                     0
# CODE_GENDER            0
# FLAG_OWN_CAR           0
# FLAG_OWN_REALTY        0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# NAME_HOUSING_TYPE      0
# DAYS_BIRTH             0
# DAYS_EMPLOYED          0
# FLAG_MOBIL             0
# FLAG_WORK_PHONE        0
# FLAG_PHONE             0
# FLAG_EMAIL             0
# CNT_FAM_MEMBERS        0
# dtype: int64

# %%
## merge CSV that has been cleaned
cr = pd.read_csv('CRUpdate2.csv')
cr.head()

cr.keys()

del cr['Unnamed: 0']
cr.head()
cr1 = cr[['ID', 'APPROVAL']]
cr1.head()
# Out:
#         ID APPROVAL
# 0  5001711      YES
# 1  5001712       NO
# 2  5001713      YES
# 3  5001714      YES
# 4  5001715      YES

# %%
new = data.merge(cr1, on='ID', how='inner')
new.head()
# Out:
#         ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804            1             1                1             0
# 1  5008805            1             1                1             0
# 2  5008806            1             1                1             0
# 3  5008808            0             0                1             0
# 4  5008809            0             0                1             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0            427500                5                   3                  3
# 1            427500                5                   3                  3
# 2            112500                5                   1                  4
# 3            270000                3                   1                  0
# 4            270000                3                   1                  0
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0                 4      -12005          -4542           1                1
# 1                 4      -12005          -4542           1                1
# 2                 5      -21474          -1134           1                0
# 3                 5      -19110          -3051           1                0
# 4                 5      -19110          -3051           1                0
#
#    FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS APPROVAL
# 0           0           0                2      YES
# 1           0           0                2      YES
# 2           0           0                2       NO
# 3           1           1                1      YES
# 4           1           1                1      YES

# %%
# loan_approved = {'NO' : 0, 'YES' : 1}
# new.replace({'APPROVAL': loan_approved}, inplace=True)

# %%
new['APPROVAL'] = new['APPROVAL'].astype('category')

new.head()
# Out:
#         ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804            1             1                1             0
# 1  5008805            1             1                1             0
# 2  5008806            1             1                1             0
# 3  5008808            0             0                1             0
# 4  5008809            0             0                1             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0            427500                5                   3                  3
# 1            427500                5                   3                  3
# 2            112500                5                   1                  4
# 3            270000                3                   1                  0
# 4            270000                3                   1                  0
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0                 4      -12005          -4542           1                1
# 1                 4      -12005          -4542           1                1
# 2                 5      -21474          -1134           1                0
# 3                 5      -19110          -3051           1                0
# 4                 5      -19110          -3051           1                0
#
#    FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS APPROVAL
# 0           0           0                2      YES
# 1           0           0                2      YES
# 2           0           0                2       NO
# 3           1           1                1      YES
# 4           1           1                1      YES

# %% [markdown]
# ### TRAIN / TEST SPLIT

# %%
#store target variable 
y = new['APPROVAL']
X = new.drop(['APPROVAL'], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=3)
X_train.shape
# Out:
# (27342, 17)

# %%
X_train.isnull().sum()
# Out:
# ID                     0
# CODE_GENDER            0
# FLAG_OWN_CAR           0
# FLAG_OWN_REALTY        0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# NAME_HOUSING_TYPE      0
# DAYS_BIRTH             0
# DAYS_EMPLOYED          0
# FLAG_MOBIL             0
# FLAG_WORK_PHONE        0
# FLAG_PHONE             0
# FLAG_EMAIL             0
# CNT_FAM_MEMBERS        0
# dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

param_grid = {"n_estimators" : [10, 20, 50, 100],
             "max_depth" : [None, 6, 8, 10],
             "max_leaf_nodes": [None, 5, 10, 20], 
             "min_impurity_split": [0.1, 0.2, 0.3, 0.4]}

# %%
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(model, param_grid=param_grid, cv=3, verbose=2)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 256 candidates, totalling 768 fits
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total=   0.9s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total=   1.6s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total=   2.0s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total=   2.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total=   1.8s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total=   4.0s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total=   3.5s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total=   3.6s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total=   2.0s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total=   1.7s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total=   1.7s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total=   3.5s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total=   3.3s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total=   3.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total=   0.7s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total=   0.9s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total=   0.7s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total=   2.0s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total=   1.9s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total=   1.7s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total=   3.3s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total=   3.2s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total=   3.2s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total=   1.6s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total=   1.3s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total=   2.7s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total=   2.6s
# [CV] max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total=   3.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total=   1.1s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=   0.9s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=   0.9s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total=   1.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total=   1.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=100, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100, total=   2.5s
# [CV] max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=5, min_impurity_split=0.4, n_estimators=100, total=   1.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=10, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=20, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50, total=   1.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=50, total=   0.7s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100, total=   1.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.1, n_estimators=100, total=   1.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=   0.9s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=   0.7s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total=   1.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total=   1.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total=   1.1s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total=   1.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=   0.9s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=   0.7s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total=   1.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total=   1.2s
# [CV] max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total=   1.3s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=   0.9s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total=   1.3s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=   0.7s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=   1.0s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total=   1.5s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total=   1.3s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total=   1.6s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=   0.3s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=   0.6s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=   0.7s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total=   1.5s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=   0.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=   0.5s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=   0.8s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=   0.9s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=   0.9s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total=   1.4s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total=   1.2s
# [CV] max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=None, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total=   1.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total=   0.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total=   0.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=20, total=   0.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total=   1.1s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total=   1.0s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=50, total=   0.8s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total=   1.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total=   1.8s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.1, n_estimators=100, total=   1.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=10, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total=   0.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total=   0.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total=   1.0s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total=   1.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=50, total=   1.1s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total=   1.8s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total=   2.0s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.2, n_estimators=100, total=   2.1s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=20, total=   0.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total=   0.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total=   1.0s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=50, total=   0.8s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total=   1.5s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total=   1.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.3, n_estimators=100, total=   1.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total=   0.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total=   0.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total=   1.0s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=50, total=   0.7s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total=   1.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total=   1.4s
# [CV] max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=None, min_impurity_split=0.4, n_estimators=100, total=   1.4s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=   0.5s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=   0.5s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=50, total=   0.5s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total=   1.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total=   0.9s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.1, n_estimators=100, total=   1.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=   0.5s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=   0.5s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=50, total=   0.5s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total=   1.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total=   1.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.2, n_estimators=100, total=   1.0s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=20, total=   0.3s
# [CV] max_depth=6, max_leaf_nodes=5, min_impurity_split=0.3, n_estimators=50
# ...
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=20, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=   0.6s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=50, total=   0.6s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total=   1.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total=   1.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.2, n_estimators=100, total=   1.8s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=   0.3s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=10, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=   0.8s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=   0.5s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=20, total=   0.6s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=50, total=   0.8s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total=   1.6s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total=   1.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.3, n_estimators=100, total=   1.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total=   1.3s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total=   1.2s
# [CV] max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=10, min_impurity_split=0.4, n_estimators=100, total=   1.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=   0.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=   0.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=20, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=   0.8s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=50, total=   1.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total=   2.1s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total=   1.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.1, n_estimators=100, total=   1.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=10, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=   0.6s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=   0.6s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=20, total=   0.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=   1.1s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=   1.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=50, total=   0.8s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total=   1.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total=   1.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.2, n_estimators=100, total=   1.6s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   0.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=   0.5s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=20, total=   0.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=   1.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=   0.8s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total=   1.5s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total=   2.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.3, n_estimators=100, total=   1.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=10, total=   0.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=   0.5s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=   0.3s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=20, total=   0.6s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=   1.2s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=50, total=   0.7s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total=   1.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total=   1.4s
# [CV] max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100
# [CV]  max_depth=10, max_leaf_nodes=20, min_impurity_split=0.4, n_estimators=100, total=   1.3s
# [Parallel(n_jobs=1)]: Done 768 out of 768 | elapsed:  9.9min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [None, 6, 8, 10],
#                          'max_leaf_nodes': [None, 5, 10, 20],
#                          'min_impurity_split': [0.1, 0.2, 0.3, 0.4],
#                          'n_estimators': [10, 20, 50, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
print(f"Best parameters: {grid.best_params_}")
print(f"Test set score: {grid.score(X_test, y_test)}")
# Out:
# Best parameters: {'max_depth': None, 'max_leaf_nodes': None, 'min_impurity_split': 0.3, 'n_estimators': 100}
# Test set score: 0.7156335710367526

# %%
print(f"Train set score: {grid.score(X_train, y_train)}")
# Out:
# Train set score: 0.9128081340062907
